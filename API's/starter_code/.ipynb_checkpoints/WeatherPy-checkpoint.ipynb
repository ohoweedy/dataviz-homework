# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt

# Set today's date
todays_date = dt.date.today().strftime("%m/%d/%Y")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create city data DataFrame
city_data_pd = pd.DataFrame({"City": [""], "Cloudiness": [""], "Country": [""],
                            "Date": [""], "Humidity": [""], "Lat": [""], "Lng": [""],
                            "Max Temp": [""], "Wind Speed": [""]})

# %%
# Set units as Imperial
units = "Imperial"

# For loop to process and pull all city temperature data
for city in cities:
    try:
        url = "http://api.openweathermap.org/data/2.5/weather?"
        query_url = f"{url}&appid={api_key}&q={city}&units={units}"
        
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        
        # Print city number and city name as loop is being processed
        city_number = weather_json["id"]
        print(f"City Name: {city}, City Number: {city_number}")      
      
        # Pull specific json data and store into variables
        cloudiness = weather_json["clouds"]["all"]
        country = weather_json["sys"]["country"]
        date = weather_json["dt"]
        humidity = weather_json["main"]["humidity"]
        lat = weather_json["coord"]["lat"]
        lng = weather_json["coord"]["lon"]
        city = weather_json["name"]
        max_temp = weather_json["main"]["temp_max"]
        wind_speed = weather_json["wind"]["speed"]
        
        # Append into a DataFrame
        city_data_pd = city_data_pd.append({'City' : city, 'Cloudiness' : cloudiness, 
                                           'Country': country, 'Date': date, 'Humidity': humidity,
                                           'Lat' : lat, 'Lng' : lng, 'Max Temp' : max_temp,
                                           'Wind Speed' : wind_speed}, ignore_index=True)
    except KeyError:
        print("Continuing with the code...")
# Out:
# City Name: saint-philippe, City Number: 6138908
# City Name: oranjemund, City Number: 3354071
# City Name: ponta delgada, City Number: 3372783
# City Name: ribeira grande, City Number: 3372707
# City Name: new norfolk, City Number: 2155415
# City Name: taoudenni, City Number: 2450173
# City Name: georgetown, City Number: 3378644
# Continuing with the code...
# City Name: caravelas, City Number: 3466980
# City Name: san rafael del sur, City Number: 3616594
# City Name: batagay-alyta, City Number: 2027042
# City Name: ayapa, City Number: 3532526
# City Name: touros, City Number: 3386213
# City Name: ilulissat, City Number: 3423146
# City Name: te anau, City Number: 2181625
# City Name: bluff, City Number: 2175403
# City Name: chara, City Number: 262462
# City Name: bled, City Number: 3203925
# City Name: beloha, City Number: 1067565
# Continuing with the code...
# City Name: sao joao da barra, City Number: 3448903
# City Name: ratnagiri, City Number: 1258338
# City Name: rivers, City Number: 6122707
# City Name: hermanus, City Number: 3366880
# City Name: floriano, City Number: 3399506
# City Name: butaritari, City Number: 2110227
# City Name: dwarka, City Number: 1273294
# City Name: vaini, City Number: 1273574
# City Name: tuktoyaktuk, City Number: 6170031
# City Name: puerto ayora, City Number: 3652764
# City Name: muborak, City Number: 1216475
# City Name: ponta do sol, City Number: 3453439
# City Name: porbandar, City Number: 1259395
# City Name: severo-kurilsk, City Number: 2121385
# City Name: grindavik, City Number: 3416888
# City Name: arraial do cabo, City Number: 3471451
# City Name: haines junction, City Number: 5969025
# City Name: alta floresta, City Number: 6316343
# City Name: bonthe, City Number: 2409914
# City Name: ushuaia, City Number: 3833367
# City Name: huarmey, City Number: 3939168
# City Name: pula, City Number: 3658053
# City Name: tandil, City Number: 3427833
# City Name: saskylakh, City Number: 2017155
# City Name: mataura, City Number: 6201424
# Continuing with the code...
# City Name: tautira, City Number: 4033557
# City Name: yulara, City Number: 6355222
# City Name: tando adam, City Number: 1163967
# City Name: clyde river, City Number: 5924351
# City Name: college, City Number: 5859699
# City Name: souillac, City Number: 3026644
# City Name: hithadhoo, City Number: 1282256
# City Name: yellowknife, City Number: 6185377
# Continuing with the code...
# City Name: punta arenas, City Number: 3874787
# City Name: rikitea, City Number: 4030556
# City Name: albany, City Number: 5106834
# City Name: cape town, City Number: 3369157
# City Name: jamestown, City Number: 2069194
# City Name: lebu, City Number: 344979
# City Name: yerbogachen, City Number: 2012956
# City Name: ravar, City Number: 118704
# Continuing with the code...
# City Name: faya, City Number: 110690
# City Name: brigantine, City Number: 4500920
# City Name: mar del plata, City Number: 3863379
# City Name: naze, City Number: 2337542
# City Name: cape girardeau, City Number: 4379966
# City Name: alofi, City Number: 4036284
# City Name: thompson, City Number: 6165406
# City Name: bambous virieux, City Number: 1106677
# City Name: kaitangata, City Number: 2208248
# City Name: eydhafushi, City Number: 1337606
# City Name: bethel, City Number: 5880568
# City Name: acapulco, City Number: 3533462
# City Name: sironj, City Number: 1256064
# City Name: vestmanna, City Number: 2610343
# City Name: busselton, City Number: 2075265
# City Name: ixtapa, City Number: 4004293
# City Name: liling, City Number: 1803616
# City Name: armidale, City Number: 2177671
# City Name: kapaa, City Number: 5848280
# Continuing with the code...
# City Name: bredasdorp, City Number: 1015776
# Continuing with the code...
# City Name: rio gallegos, City Number: 3838859
# City Name: dongsheng, City Number: 1788268
# City Name: kamenka, City Number: 553725
# City Name: aklavik, City Number: 5882953
# City Name: akdepe, City Number: 601551
# City Name: tarko-sale, City Number: 1490085
# City Name: weligama, City Number: 1223738
# City Name: nikolskoye, City Number: 546105
# City Name: chuy, City Number: 3443061
# City Name: hazaribag, City Number: 1270164
# City Name: tilichiki, City Number: 2120591
# City Name: riyadh, City Number: 108410
# City Name: filingue, City Number: 2444995
# City Name: qaqortoq, City Number: 3420846
# City Name: hilo, City Number: 5855927
# Continuing with the code...
# City Name: chokurdakh, City Number: 2126123
# City Name: salalah, City Number: 286621
# City Name: hobart, City Number: 2163355
# City Name: sayan, City Number: 34846
# City Name: fortuna, City Number: 2517679
# City Name: cumbum, City Number: 1273795
# City Name: tiarei, City Number: 4033356
# Continuing with the code...
# City Name: cayenne, City Number: 3382160
# City Name: qinzhou, City Number: 1797551
# City Name: barrow, City Number: 3833859
# City Name: daeni, City Number: 679830
# Continuing with the code...
# City Name: qaanaaq, City Number: 3831208
# City Name: norrkoping, City Number: 2688368
# City Name: dzilam gonzalez, City Number: 3529654
# City Name: atuona, City Number: 4020109
# Continuing with the code...
# City Name: katsuura, City Number: 1865309
# City Name: mandalgovi, City Number: 2030065
# City Name: sibolga, City Number: 1213855
# City Name: leningradskiy, City Number: 2123814
# Continuing with the code...
# City Name: madang, City Number: 2091996
# City Name: east london, City Number: 1006984
# City Name: saint george, City Number: 262462
# City Name: nome, City Number: 4732862
# City Name: zorritos, City Number: 3690608
# Continuing with the code...
# City Name: victoria, City Number: 1733782
# Continuing with the code...
# City Name: port hedland, City Number: 2063042
# Continuing with the code...
# City Name: itarema, City Number: 3393692
# City Name: constitucion, City Number: 4011743
# City Name: saldanha, City Number: 2737599
# City Name: merauke, City Number: 2082539
# City Name: kenora, City Number: 5991056
# Continuing with the code...
# City Name: kodiak, City Number: 4407665
# Continuing with the code...
# City Name: mahebourg, City Number: 934322
# City Name: ancud, City Number: 3899695
# City Name: kirov, City Number: 548408
# City Name: quelimane, City Number: 1028434
# City Name: urengoy, City Number: 1488414
# City Name: byron bay, City Number: 2172880
# City Name: padang, City Number: 1633419
# City Name: necochea, City Number: 3430443
# City Name: wanning, City Number: 3220813
# City Name: provideniya, City Number: 4031574
# City Name: belen, City Number: 321572
# Continuing with the code...
# City Name: sitka, City Number: 4267710
# City Name: lichinga, City Number: 1043893
# City Name: dingle, City Number: 1714733
# City Name: nola, City Number: 2383827
# City Name: the valley, City Number: 3573374
# City Name: dicabisagan, City Number: 1715015
# City Name: aksha, City Number: 2028028
# City Name: murdochville, City Number: 6943820
# City Name: khatanga, City Number: 2022572
# City Name: nara, City Number: 1855612
# City Name: sao filipe, City Number: 3374210
# City Name: balkanabat, City Number: 161616
# City Name: neuquen, City Number: 3843123
# City Name: hamilton, City Number: 5969785
# City Name: port macquarie, City Number: 2152659
# City Name: santa rosa, City Number: 3835994
# City Name: kouroussa, City Number: 2418437
# City Name: madingou, City Number: 2257990
# Continuing with the code...
# City Name: port alfred, City Number: 964432
# City Name: longyearbyen, City Number: 2729907
# City Name: zile, City Number: 737054
# City Name: antalaha, City Number: 1071296
# City Name: jevnaker, City Number: 3150842
# Continuing with the code...
# City Name: tasiilaq, City Number: 3424607
# City Name: hay river, City Number: 5972762
# City Name: geraldton, City Number: 5960603
# City Name: chhatarpur, City Number: 1274337
# City Name: mnogovershinnyy, City Number: 2019935
# City Name: dubbo, City Number: 2168305
# City Name: fayaoue, City Number: 2141305
# City Name: codrington, City Number: 2160063
# City Name: venado tuerto, City Number: 3833062
# City Name: obo, City Number: 236950
# City Name: honiara, City Number: 2108502
# City Name: westport, City Number: 2960970
# City Name: palmerston north, City Number: 2185018
# City Name: araouane, City Number: 2460954
# City Name: san andres, City Number: 1690438
# City Name: chake chake, City Number: 160677
# City Name: humberto de campos, City Number: 3398428
# City Name: alexandria, City Number: 4314550
# Continuing with the code...
# City Name: chapais, City Number: 5919850
# Continuing with the code...
# City Name: lundazi, City Number: 909299
# City Name: kastamonu, City Number: 743882
# City Name: castro, City Number: 3896218
# City Name: coquimbo, City Number: 3893629
# City Name: kropotkin, City Number: 540761
# City Name: ziway, City Number: 325579
# City Name: tagusao, City Number: 1684245
# City Name: upernavik, City Number: 3418910
# City Name: lagoa, City Number: 2267254
# City Name: puro, City Number: 1706889
# City Name: ojinaga, City Number: 3994469
# City Name: lompoc, City Number: 5367788
# City Name: talnakh, City Number: 1490256
# City Name: saint leonard, City Number: 4350049
# City Name: lere, City Number: 2428042
# City Name: mayumba, City Number: 2399001
# City Name: wazirganj, City Number: 1270021
# City Name: airai, City Number: 1651810
# Continuing with the code...
# City Name: kirakira, City Number: 2178753
# City Name: tsagan aman, City Number: 481117
# City Name: sedona, City Number: 5313667
# City Name: alice springs, City Number: 2077895
# Continuing with the code...
# City Name: port hawkesbury, City Number: 6111867
# City Name: gumdag, City Number: 161943
# City Name: baglung, City Number: 1283711
# Continuing with the code...
# City Name: dikson, City Number: 1507390
# City Name: sorland, City Number: 3137469
# City Name: isangel, City Number: 2136825
# City Name: saint anthony, City Number: 5606187
# City Name: ugoofaaru, City Number: 1337619
# City Name: fort nelson, City Number: 5955902
# City Name: hovd, City Number: 7626384
# City Name: hirado, City Number: 1862555
# City Name: santo antonio do ica, City Number: 3662395
# City Name: biswan, City Number: 1275435
# City Name: tottori, City Number: 1849892
# City Name: batagay, City Number: 2027044
# Continuing with the code...
# City Name: meadow lake, City Number: 6071421
# City Name: saint-pierre, City Number: 2995603
# City Name: avera, City Number: 4231997
# City Name: sola, City Number: 3137942
# City Name: kijang, City Number: 1842966
# City Name: teya, City Number: 3526662
# City Name: ciamis, City Number: 1647149
# Continuing with the code...
# City Name: san quintin, City Number: 1688687
# City Name: vila velha, City Number: 6320062
# Continuing with the code...
# City Name: avarua, City Number: 4035715
# City Name: port elizabeth, City Number: 4501427
# City Name: maceio, City Number: 3395981
# City Name: samarai, City Number: 2132606
# Continuing with the code...
# City Name: barabinsk, City Number: 1510916
# City Name: bireun, City Number: 1215350
# City Name: daru, City Number: 2409663
# City Name: bolshoye nagatkino, City Number: 480884
# City Name: pisco, City Number: 3932145
# City Name: cherskiy, City Number: 2126199
# City Name: whitehorse, City Number: 6180550
# City Name: tual, City Number: 1623197
# City Name: camacha, City Number: 2270385
# City Name: evensk, City Number: 2125693
# City Name: beringovskiy, City Number: 2126710
# City Name: puerto escondido, City Number: 3520994
# City Name: elizabethton, City Number: 4620634
# City Name: norman wells, City Number: 6089245
# City Name: kendari, City Number: 1640344
# City Name: hofn, City Number: 2630299
# City Name: myitkyina, City Number: 1307741
# City Name: san miguel, City Number: 3430545
# City Name: yumen, City Number: 1528998
# City Name: solnechnyy, City Number: 2016307
# City Name: ayan, City Number: 749747
# City Name: reconquista, City Number: 3429594
# City Name: singkang, City Number: 1732871
# City Name: lavrentiya, City Number: 4031637
# City Name: port lincoln, City Number: 2063036
# City Name: merritt island, City Number: 4164092
# City Name: nabire, City Number: 1634614
# City Name: abu samrah, City Number: 172515
# City Name: tiksi, City Number: 2015306
# City Name: boa vista, City Number: 3664980
# City Name: tuatapere, City Number: 2180815
# City Name: duobao, City Number: 1811829
# City Name: atar, City Number: 2381334
# Continuing with the code...
# City Name: kopavogur, City Number: 3415212
# City Name: whyalla, City Number: 2058430
# Continuing with the code...
# City Name: karratha, City Number: 6620339
# City Name: chum phae, City Number: 1611026
# City Name: nador, City Number: 2541479
# City Name: rock springs, City Number: 5836898
# City Name: esperance, City Number: 3573739
# City Name: parana, City Number: 3663516
# City Name: ust-nera, City Number: 2120048
# City Name: leticia, City Number: 3676623
# City Name: ketchikan, City Number: 5554428
# City Name: faanui, City Number: 4034551
# City Name: yingcheng, City Number: 1786640
# City Name: kruisfontein, City Number: 986717
# City Name: matara, City Number: 3948642
# City Name: gladstone, City Number: 2165478
# Continuing with the code...
# City Name: novoagansk, City Number: 1497210
# City Name: upington, City Number: 945945
# City Name: houma, City Number: 1784874
# City Name: vostok, City Number: 2013279
# City Name: porto tolle, City Number: 3170070
# City Name: muzhi, City Number: 1498161
# City Name: anadyr, City Number: 2127202
# Continuing with the code...
# City Name: havoysund, City Number: 779622
# City Name: moba, City Number: 212962
# Continuing with the code...
# City Name: lovozero, City Number: 533933
# City Name: vardo, City Number: 4372777
# City Name: florianopolis, City Number: 3463237
# Continuing with the code...
# City Name: saint-augustin, City Number: 3031582
# City Name: okhotsk, City Number: 2122605
# City Name: areia branca, City Number: 3471609
# City Name: ukiah, City Number: 5404476
# City Name: meulaboh, City Number: 1214488
# City Name: cidreira, City Number: 3466165
# Continuing with the code...
# City Name: half moon bay, City Number: 5354943
# City Name: christchurch, City Number: 2192362
# City Name: yeppoon, City Number: 2142316
# City Name: dovbysh, City Number: 709665
# City Name: angoche, City Number: 1052944
# City Name: ahuimanu, City Number: 5856516
# Continuing with the code...
# City Name: rio grande, City Number: 3451138
# City Name: eyemouth, City Number: 2649784
# City Name: waingapu, City Number: 1622318
# City Name: anori, City Number: 3665315
# City Name: sandwick, City Number: 2640416
# City Name: porto velho, City Number: 3662762
# City Name: puqi, City Number: 1798473
# City Name: torbay, City Number: 6167817
# City Name: san cristobal, City Number: 3652462
# City Name: hasaki, City Number: 2112802
# City Name: coahuayana, City Number: 3981460
# City Name: zemio, City Number: 235826
# Continuing with the code...
# City Name: talaya, City Number: 1485724
# City Name: guarapari, City Number: 3461888
# City Name: hereford, City Number: 2647074
# City Name: noumea, City Number: 2139521
# City Name: maniitsoq, City Number: 3421982
# City Name: hambantota, City Number: 1244926
# City Name: nanortalik, City Number: 3421765
# City Name: sorong, City Number: 1626542
# City Name: lastoursville, City Number: 2399870
# City Name: tezu, City Number: 1254709
# City Name: tazovskiy, City Number: 1489853
# City Name: atambua, City Number: 1651103
# City Name: thinadhoo, City Number: 1337610
# City Name: iracoubo, City Number: 3381428
# City Name: ziro, City Number: 1252668
# City Name: elizabeth city, City Number: 4465088
# City Name: semey, City Number: 1519422
# City Name: guerrero negro, City Number: 4021858
# City Name: tomatlan, City Number: 3981391
# City Name: cap malheureux, City Number: 934649
# City Name: ostrovnoy, City Number: 556268
# City Name: jatara, City Number: 1269153
# City Name: havre-saint-pierre, City Number: 5972291
# City Name: brae, City Number: 2654970
# City Name: ahipara, City Number: 2194098
# City Name: baruun-urt, City Number: 2032614
# City Name: somerset east, City Number: 954161
# City Name: kaspiyskiy, City Number: 551846
# City Name: smithers, City Number: 6149996
# Continuing with the code...
# City Name: cabo san lucas, City Number: 3985710
# City Name: bathsheba, City Number: 3374083
# City Name: bayshore gardens, City Number: 4146934
# City Name: fairbanks, City Number: 5861897
# City Name: yanam, City Number: 1252795
# Continuing with the code...
# City Name: labuan, City Number: 1733782
# City Name: kavaratti, City Number: 1267390
# City Name: lorengau, City Number: 2092164
# City Name: bend, City Number: 5713587
# City Name: charters towers, City Number: 2171722
# Continuing with the code...
# City Name: klaksvik, City Number: 2618795
# City Name: nuevo progreso, City Number: 3520271
# City Name: deputatskiy, City Number: 2028164
# City Name: chortomlyk, City Number: 710615
# City Name: tommot, City Number: 2015179
# City Name: praia da vitoria, City Number: 3372760
# City Name: belmonte, City Number: 8010472
# City Name: nacala, City Number: 1035025
# City Name: ozinki, City Number: 513328
# City Name: rundu, City Number: 3353383
# City Name: road town, City Number: 3577430
# City Name: sikasso, City Number: 2451185
# City Name: kiunga, City Number: 2093846
# City Name: khani, City Number: 610864
# City Name: entre rios, City Number: 3464100
# Continuing with the code...
# City Name: pacific grove, City Number: 5380437
# City Name: henties bay, City Number: 3356832
# City Name: carnarvon, City Number: 1014034
# City Name: breves, City Number: 3404817
# City Name: buluang, City Number: 1717512
# City Name: kavieng, City Number: 2094342
# Continuing with the code...
# City Name: broome, City Number: 2656067
# City Name: pevek, City Number: 2122090
# City Name: biankouma, City Number: 2291666
# City Name: vila franca do campo, City Number: 3372472
# City Name: nouakchott, City Number: 2377450
# City Name: sarkand, City Number: 1519691
# City Name: bandarbeyla, City Number: 64814
# City Name: shaowu, City Number: 1795857
# Continuing with the code...
# City Name: birjand, City Number: 140463
# City Name: goiatuba, City Number: 3462371
# Continuing with the code...
# City Name: kutum, City Number: 371745
# City Name: lira, City Number: 230166
# City Name: nodeland, City Number: 3144534
# Continuing with the code...
# City Name: livingston, City Number: 4073383
# City Name: southbridge, City Number: 4951594
# Continuing with the code...
# City Name: zelenodolsk, City Number: 713245
# City Name: elat, City Number: 2232283
# City Name: tateyama, City Number: 1849876
# City Name: djambala, City Number: 2260401
# City Name: manokwari, City Number: 1636308
# Continuing with the code...
# City Name: krynychky, City Number: 704079
# City Name: ler, City Number: 3146125
# City Name: tondano, City Number: 1623424
# City Name: poum, City Number: 787487
# City Name: severodvinsk, City Number: 496285
# City Name: porto, City Number: 2735943
# City Name: pedasi, City Number: 3703239
# City Name: simga, City Number: 1256245
# City Name: livani, City Number: 457860
# City Name: mutoko, City Number: 884927
# City Name: kahului, City Number: 5847411
# City Name: fougamou, City Number: 2400578
# City Name: paez, City Number: 3668572
# City Name: flinders, City Number: 6255012
# City Name: zyryanka, City Number: 2119283
# City Name: grand-santi, City Number: 3381538
# City Name: pocatello, City Number: 5604045
# City Name: sioux lookout, City Number: 6148373
# City Name: inverness, City Number: 2646088
# City Name: dinard, City Number: 3021351
# City Name: marsa matruh, City Number: 352733
# Continuing with the code...
# City Name: ismailia, City Number: 361055
# City Name: salinopolis, City Number: 3389822
# City Name: west bay, City Number: 2654726
# Continuing with the code...
# City Name: kanungu, City Number: 232287
# City Name: ous, City Number: 1495812
# City Name: north myrtle beach, City Number: 4589446
# City Name: abha, City Number: 110690
# City Name: rio pardo de minas, City Number: 3451100
# City Name: neiafu, City Number: 4032420
# City Name: aksu, City Number: 1524298
# City Name: saint-georges, City Number: 6295855
# City Name: sabha, City Number: 2212775
# City Name: peleduy, City Number: 2018069
# City Name: cranbourne, City Number: 2170078
# City Name: dzhebariki-khaya, City Number: 2024626
# Continuing with the code...
# City Name: urcos, City Number: 3926462
# City Name: port blair, City Number: 1259385
# City Name: gizo, City Number: 6693679
# Continuing with the code...
# City Name: muroto, City Number: 1856392
# City Name: bashmakovo, City Number: 578842
# City Name: saalfeld, City Number: 2842688
# City Name: sechura, City Number: 3691954
# City Name: mbaiki, City Number: 2384770
# City Name: malazgirt, City Number: 304916
# Continuing with the code...
# City Name: thunder bay, City Number: 6166142
# City Name: kuito, City Number: 3348078
# City Name: shar, City Number: 2347266
# Continuing with the code...
# City Name: ambilobe, City Number: 1082243
# City Name: san patricio, City Number: 3437029
# Continuing with the code...
# City Name: ulladulla, City Number: 2145554
# City Name: umm lajj, City Number: 100926
# City Name: namibe, City Number: 3347019
# City Name: san isidro, City Number: 1689639
# City Name: mendi, City Number: 331038
# City Name: mount isa, City Number: 2065594
# City Name: balkhash, City Number: 1525798
# City Name: cockburn town, City Number: 3576994
# City Name: chaman, City Number: 1181611
# City Name: jalna, City Number: 1269395
# City Name: luanda, City Number: 2240449
# City Name: mehamn, City Number: 778707
# City Name: asbestovskiy, City Number: 1511329
# City Name: zeya, City Number: 2012593
# Continuing with the code...
# City Name: portland, City Number: 5746545
# City Name: san juan, City Number: 3837213
# City Name: ossora, City Number: 2122389
# City Name: totness, City Number: 4589590
# City Name: nuuk, City Number: 3421319
# City Name: ginda, City Number: 1253628
# City Name: yuli, City Number: 2347468
# City Name: raudeberg, City Number: 3146487
# City Name: beyneu, City Number: 610298
# City Name: mujiayingzi, City Number: 2035707
# City Name: cairns, City Number: 2172797
# City Name: constancia, City Number: 3564124
# City Name: tengzhou, City Number: 1793036
# City Name: petropavlovsk-kamchatskiy, City Number: 2122104
# City Name: lufilufi, City Number: 4035249
# City Name: council bluffs, City Number: 4852832
# City Name: codajas, City Number: 3664525
# City Name: kungurtug, City Number: 1501377
# City Name: pombia, City Number: 3170346
# City Name: atkinson, City Number: 4893581
# City Name: garowe, City Number: 58933
# City Name: statesboro, City Number: 4224413
# City Name: itaituba, City Number: 3397967
# City Name: miles city, City Number: 5666176
# City Name: pravdinsk, City Number: 505599
# City Name: monywa, City Number: 1308522
# City Name: ronne, City Number: 2991703
# Continuing with the code...
# City Name: makakilo city, City Number: 5850554
# City Name: port-gentil, City Number: 2396518
# City Name: saint-hubert, City Number: 2787409
# City Name: goundi, City Number: 2431736
# City Name: algiers, City Number: 4335045
# City Name: kyzyl-suu, City Number: 1527497
# City Name: nishihara, City Number: 1850144
# City Name: navlya, City Number: 523186
# City Name: sistranda, City Number: 3139597
# City Name: kaset sombun, City Number: 1610187
# City Name: winneba, City Number: 2294034
# Continuing with the code...
# City Name: lubliniec, City Number: 3092906
# City Name: eseka, City Number: 2231881
# City Name: havelock, City Number: 4470244
# Continuing with the code...
# City Name: aviles, City Number: 3129135
# Continuing with the code...
# City Name: buribay, City Number: 570813
# City Name: naberera, City Number: 152042
# City Name: bubaque, City Number: 2374583
# City Name: gat, City Number: 2249901
# City Name: ornskoldsvik, City Number: 2686469
# City Name: porto nacional, City Number: 3452711
# City Name: kemi, City Number: 653281
# City Name: qinhuangdao, City Number: 1797595
# City Name: fairlie, City Number: 4682762
# City Name: slavyanka, City Number: 2016430
# City Name: buala, City Number: 2109528
# City Name: yamethin, City Number: 1285899
# City Name: alora, City Number: 3361025
# City Name: ebbs, City Number: 2780579
# City Name: pyapon, City Number: 1299237
# City Name: bandrele, City Number: 1090397
# Continuing with the code...
# City Name: vanderhoof, City Number: 6173361
# City Name: billings, City Number: 5640350
# City Name: balgazyn, City Number: 1510960
# City Name: lodja, City Number: 211647
# Continuing with the code...
# Continuing with the code...
# City Name: la ronge, City Number: 6050066
# City Name: okakarara, City Number: 3354876
# City Name: peqin, City Number: 3184497
# City Name: funtua, City Number: 2342490
# City Name: marystown, City Number: 6067472
# City Name: grand gaube, City Number: 934479
# Continuing with the code...
# City Name: bredy, City Number: 1508811
# City Name: pauini, City Number: 3662927
# City Name: vallenar, City Number: 3868633
# City Name: san ignacio, City Number: 3872175
# City Name: opuwo, City Number: 3354077
# City Name: jalu, City Number: 86049
# City Name: dolores, City Number: 3442750
# City Name: roebourne, City Number: 2062276
# City Name: borogontsy, City Number: 2026160

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export to csv
city_data_pd.to_csv(output_data_file)

# Drop empty row and all NaN's
city_data_pd = city_data_pd.dropna(how='all')
city_data_pd = city_data_pd.drop([0])

# Preview DataFrame
city_data_pd.head()
# Out:
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 1  Saint-Philippe         90      CA  1554346444       69  45.36  -73.48
# 2      Oranjemund         92      ZA  1554346487       97 -28.55   16.43
# 3   Ponta Delgada         40      PT  1554346464       76  37.73  -25.67
# 4  Ribeira Grande         92      PT  1554346487      100  38.52   -28.7
# 5     New Norfolk         20      AU  1554346454       44 -42.78  147.06
#
#   Max Temp Wind Speed
# 1    37.99      17.22
# 2     58.5       5.64
# 3     55.4      10.29
# 4    59.49      20.85
# 5    64.99       8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Convert columns from string to float
columns_to_convert = ['Cloudiness','Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']

for column in columns_to_convert:
    city_data_pd[column] = city_data_pd[column].astype(float)
    
# Set x and y variables
x1 = city_data_pd["Lat"]
y1 = city_data_pd["Max Temp"]

# Build scatter plot
plt.scatter(x1, y1, marker="o", facecolors="lightcoral", edgecolors="black", alpha=0.8, linewidth=1, label="Lat v. Temp")

plt.title(f"City Latitude vs. Max Temperature ({todays_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.xlim(-80,100)
plt.ylim(-100,150)

# Save image
plt.savefig("Images/LatitudeVsTemperature.png")

# Show image
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Set x and y variables
x2 = city_data_pd["Lat"]
y2 = city_data_pd["Humidity"]

# Build scatter plot
plt.scatter(x2, y2, marker="o", facecolors="blue", edgecolors="black", alpha=0.8, linewidth=1, label="Lat v. Humid")

plt.title(f"City Latitude vs. Humidity ({todays_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.xlim(-80,100)
plt.ylim(-20,120)

# Save image
plt.savefig("Images/LatitudeVsHumidity.png")

# Show image
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Set x and y variables
x3 = city_data_pd["Lat"]
y3 = city_data_pd["Cloudiness"]

# Build scatter plot
plt.scatter(x3, y3, marker="o", facecolors="green", edgecolors="black", alpha=0.8, linewidth=1, label="Lat v. Cloud")

plt.title(f"City Latitude vs. Cloudiness ({todays_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.xlim(-80,100)
plt.ylim(-20,120)

# Save image
plt.savefig("Images/LatitudeVsCloudiness.png")

# Show image
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Set x and y variables
x4 = city_data_pd["Lat"]
y4 = city_data_pd["Wind Speed"]

# Build scatter plot
plt.scatter(x4, y4, marker="o", facecolors="orange", edgecolors="black", alpha=0.8, linewidth=1, label="Lat v. Wind")

plt.title(f"City Latitude vs. Wind Speed ({todays_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.xlim(-80,100)
plt.ylim(-5,45)

# Save image
plt.savefig("Images/LatitudeVsWindSpeed.png")

# Show image
plt.show()

# %%
# 4 observable trends:
# 1. As latitudes get closer to zero (the equator), temperature data is more clustered
# around higher temperatures.
# 2. As latitudes get closer to zero (the equator), humidity data is a bit more scattered, 
# but generally more clustered from -10 degrees Lat to 0 degrees Lat.
# 3. Latitude vs cloudiness data, as well as latitude vs wind speed data, is a lot more
# scattered. There are generally higher wind speeds as you go further away from the equator, however.
# 4. The data representation is also dependent on when the data is pulled, as seasonal factors
# play a big part in current weather conditions.

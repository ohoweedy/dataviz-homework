# %%
# We will attempt to get data on regular season wins and postseason wins for each team going back twenty years or 
#as long as the API has data for.  We are using sportsradar api

# %%
# Sportradar documentation: 

#This endpoint retrieves the current Standings.

# https://api.sportradar.us/nba/{access_level}/{version}/{language_code}/seasons/{season_year}/{nba_season}/
#standings.{format}?api_key={your_api_key}

# %%
# We will run a test first, but some of the items for the test will persist

# %%
#dependencies


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from pprint import pprint

# %%
#Parameters


access_level = "trial"
version = "v5"
language_code = "en"
#Season year in Four Digit Format; Also, will need to make this a list when not in "test" mode
season_year = ["2015","2016"]
#nba_season refers to Pre, Regular, or Post; options are PRE, REG or PST
nba_season = "REG"
format_parameter = "json"
#need to remove key if it works
api_key = "5p57fad3wt25nbjevw4bzfnq"
base_url = "https://api.sportradar.us/nba/"

# %%
#NBA Specific Info Needed for Queries:

# %%
#Eastern_Conference_Divisions = ["Atlantic","Central","Southeast"]

# %%
#Western_Conference_Divisions = ["Northwest","Pacific","Southwest"]

# %%
#Atlantic_Division_Teams = ["Raptors", "76ers","Celtics","Nets","Knicks"]
#Central_Division_Teams = ["Bucks","Pacers","Pistons","Bulls","Cavaliers"]

# %%
# Lists to Hold Data

teams = []
division_list=[]
conference_list=[]
wins = []
losses = []
win_pct = []
points_for_list=[]
points_against_list=[]
cities = []
season_list =[]

# %%
#url assembly

#nba_url = f"{base_url}{access_level}/{version}/{language_code}/seasons/{season}/{nba_season}/standings/.{format_parameter}?api_key={api_key}"

#print(nba_url)

# %%
for season in season_year:
    #Finish URL 
    nba_url = f"{base_url}{access_level}/{version}/{language_code}/seasons/{season}/{nba_season}/standings.{format_parameter}?api_key={api_key}"
    print(nba_url)
    nba_response = requests.get(nba_url).json()
    season=season
# Out:
# https://api.sportradar.us/nba/trial/v5/en/seasons/2015/REG/standings.json?api_key=5p57fad3wt25nbjevw4bzfnq
# https://api.sportradar.us/nba/trial/v5/en/seasons/2016/REG/standings.json?api_key=5p57fad3wt25nbjevw4bzfnq

# %%
pprint(nba_response)
# Out:
# {'conferences': [{'alias': 'EASTERN',
#                   'divisions': [{'alias': 'SOUTHEAST',
#                                  'id': '54dc7348-c1d2-40d8-88b3-c4c0138e085d',
#                                  'name': 'Southeast',
#                                  'teams': [{'games_behind': {'conference': 4.0,
#                                                              'division': 0.0,
#                                                              'league': 18.0},
#                                             'id': '583ec8d4-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 33,
#                                             'market': 'Washington',
#                                             'name': 'Wizards',
#                                             'point_diff': 1.81,
#                                             'points_against': 107.38,
#                                             'points_for': 109.18,
#                                             'records': [{'losses': 6,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.667,
#                                                          'wins': 12},
#                                                         {'losses': 14,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.667,
#                                                          'wins': 28},
#                                                         {'losses': 6,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.667,
#                                                          'wins': 12},
#                                                         {'losses': 20,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.615,
#                                                          'wins': 32},
#                                                         {'losses': 8,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.5,
#                                                          'wins': 8},
#                                                         {'losses': 11,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.732,
#                                                          'wins': 30},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 4,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 3,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.571,
#                                                          'wins': 4},
#                                                         {'losses': 19,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.525,
#                                                          'wins': 21},
#                                                         {'losses': 2,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.8,
#                                                          'wins': 8},
#                                                         {'losses': 22,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.463,
#                                                          'wins': 19},
#                                                         {'losses': 8,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.5,
#                                                          'wins': 8},
#                                                         {'losses': 7,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 12,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.6,
#                                                          'wins': 18},
#                                                         {'losses': 6,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.6,
#                                                          'wins': 9}],
#                                             'reference': '1610612764',
#                                             'sr_id': 'sr:team:3431',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 1},
#                                             'win_pct': 0.598,
#                                             'wins': 49},
#                                            {'games_behind': {'conference': 10.0,
#                                                              'division': 6.0,
#                                                              'league': 24.0},
#                                             'id': '583ecb8f-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 39,
#                                             'market': 'Atlanta',
#                                             'name': 'Hawks',
#                                             'point_diff': -0.85,
#                                             'points_against': 104.01,
#                                             'points_for': 103.16,
#                                             'records': [{'losses': 5,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.722,
#                                                          'wins': 13},
#                                                         {'losses': 19,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.548,
#                                                          'wins': 23},
#                                                         {'losses': 7,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.611,
#                                                          'wins': 11},
#                                                         {'losses': 22,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.577,
#                                                          'wins': 30},
#                                                         {'losses': 10,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.375,
#                                                          'wins': 6},
#                                                         {'losses': 38,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.525,
#                                                          'wins': 42},
#                                                         {'losses': 38,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.525,
#                                                          'wins': 42},
#                                                         {'losses': 1,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 18,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.561,
#                                                          'wins': 23},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 7,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 6,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 1,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 1,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 33,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.353,
#                                                          'wins': 18},
#                                                         {'losses': 0,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 1.0,
#                                                          'wins': 5},
#                                                         {'losses': 20,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.5,
#                                                          'wins': 20},
#                                                         {'losses': 8,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.2,
#                                                          'wins': 2},
#                                                         {'losses': 21,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.488,
#                                                          'wins': 20},
#                                                         {'losses': 11,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.771,
#                                                          'wins': 37},
#                                                         {'losses': 10,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.375,
#                                                          'wins': 6},
#                                                         {'losses': 3,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 21,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.447,
#                                                          'wins': 17},
#                                                         {'losses': 8,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.467,
#                                                          'wins': 7}],
#                                             'reference': '1610612737',
#                                             'sr_id': 'sr:team:3423',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 1},
#                                             'win_pct': 0.524,
#                                             'wins': 43},
#                                            {'games_behind': {'conference': 12.0,
#                                                              'division': 8.0,
#                                                              'league': 26.0},
#                                             'id': '583ecea6-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 41,
#                                             'market': 'Miami',
#                                             'name': 'Heat',
#                                             'point_diff': 1.06,
#                                             'points_against': 102.11,
#                                             'points_for': 103.17,
#                                             'records': [{'losses': 11,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.389,
#                                                          'wins': 7},
#                                                         {'losses': 15,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.605,
#                                                          'wins': 23},
#                                                         {'losses': 7,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.611,
#                                                          'wins': 11},
#                                                         {'losses': 25,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.519,
#                                                          'wins': 27},
#                                                         {'losses': 7,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.563,
#                                                          'wins': 9},
#                                                         {'losses': 41,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.488,
#                                                          'wins': 39},
#                                                         {'losses': 41,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.488,
#                                                          'wins': 39},
#                                                         {'losses': 0,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 18,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.561,
#                                                          'wins': 23},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 1.0,
#                                                          'wins': 2},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 6,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 1.0,
#                                                          'wins': 2},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 2},
#                                                         {'losses': 27,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.4,
#                                                          'wins': 18},
#                                                         {'losses': 1,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.667,
#                                                          'wins': 2},
#                                                         {'losses': 26,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.409,
#                                                          'wins': 18},
#                                                         {'losses': 5,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 23,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.439,
#                                                          'wins': 18},
#                                                         {'losses': 13,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.735,
#                                                          'wins': 36},
#                                                         {'losses': 7,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.563,
#                                                          'wins': 9},
#                                                         {'losses': 5,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 13,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.594,
#                                                          'wins': 19},
#                                                         {'losses': 6,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.571,
#                                                          'wins': 8}],
#                                             'reference': '1610612748',
#                                             'sr_id': 'sr:team:3435',
#                                             'streak': {'kind': 'win',
#                                                        'length': 3},
#                                             'win_pct': 0.5,
#                                             'wins': 41},
#                                            {'games_behind': {'conference': 17.0,
#                                                              'division': 13.0,
#                                                              'league': 31.0},
#                                             'id': '583ec97e-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 46,
#                                             'market': 'Charlotte',
#                                             'name': 'Hornets',
#                                             'point_diff': 0.2,
#                                             'points_against': 104.7,
#                                             'points_for': 104.89,
#                                             'records': [{'losses': 11,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.389,
#                                                          'wins': 7},
#                                                         {'losses': 18,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.514,
#                                                          'wins': 19},
#                                                         {'losses': 13,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.278,
#                                                          'wins': 5},
#                                                         {'losses': 30,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.423,
#                                                          'wins': 22},
#                                                         {'losses': 6,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.625,
#                                                          'wins': 10},
#                                                         {'losses': 44,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.443,
#                                                          'wins': 35},
#                                                         {'losses': 44,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.443,
#                                                          'wins': 35},
#                                                         {'losses': 2,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 19,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.537,
#                                                          'wins': 22},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 3,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 2,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 2,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 42,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.276,
#                                                          'wins': 16},
#                                                         {'losses': 6,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 28,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.378,
#                                                          'wins': 17},
#                                                         {'losses': 6,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 27,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.341,
#                                                          'wins': 14},
#                                                         {'losses': 27,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.518,
#                                                          'wins': 29},
#                                                         {'losses': 6,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.625,
#                                                          'wins': 10},
#                                                         {'losses': 7,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 18,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.514,
#                                                          'wins': 19},
#                                                         {'losses': 9,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0}],
#                                             'reference': '1610612766',
#                                             'sr_id': 'sr:team:3430',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 5},
#                                             'win_pct': 0.439,
#                                             'wins': 36},
#                                            {'games_behind': {'conference': 24.0,
#                                                              'division': 20.0,
#                                                              'league': 38.0},
#                                             'id': '583ed157-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 53,
#                                             'market': 'Orlando',
#                                             'name': 'Magic',
#                                             'point_diff': -6.57,
#                                             'points_against': 107.65,
#                                             'points_for': 101.07,
#                                             'records': [{'losses': 10,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.444,
#                                                          'wins': 8},
#                                                         {'losses': 25,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.457,
#                                                          'wins': 21},
#                                                         {'losses': 13,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.278,
#                                                          'wins': 5},
#                                                         {'losses': 32,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.385,
#                                                          'wins': 20},
#                                                         {'losses': 9,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.438,
#                                                          'wins': 7},
#                                                         {'losses': 51,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.363,
#                                                          'wins': 29},
#                                                         {'losses': 51,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.363,
#                                                          'wins': 29},
#                                                         {'losses': 1,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 25,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.39,
#                                                          'wins': 16},
#                                                         {'losses': 7,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 9,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.1,
#                                                          'wins': 1},
#                                                         {'losses': 1,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 1,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 8,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.2,
#                                                          'wins': 2},
#                                                         {'losses': 1,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 1,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 1,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 46,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.246,
#                                                          'wins': 15},
#                                                         {'losses': 2,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.5,
#                                                          'wins': 2},
#                                                         {'losses': 28,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.222,
#                                                          'wins': 8},
#                                                         {'losses': 7,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 28,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.317,
#                                                          'wins': 13},
#                                                         {'losses': 22,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.511,
#                                                          'wins': 23},
#                                                         {'losses': 9,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.438,
#                                                          'wins': 7},
#                                                         {'losses': 6,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 32,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.238,
#                                                          'wins': 10},
#                                                         {'losses': 5,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5}],
#                                             'reference': '1610612753',
#                                             'sr_id': 'sr:team:3437',
#                                             'streak': {'kind': 'win',
#                                                        'length': 1},
#                                             'win_pct': 0.354,
#                                             'wins': 29}]},
#                                 {'alias': 'CENTRAL',
#                                  'id': 'f3aaf23a-1ceb-46ef-8fef-9403692e801b',
#                                  'name': 'Central',
#                                  'teams': [{'games_behind': {'conference': 2.0,
#                                                              'division': 0.0,
#                                                              'league': 16.0},
#                                             'id': '583ec773-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 31,
#                                             'market': 'Cleveland',
#                                             'name': 'Cavaliers',
#                                             'point_diff': 3.18,
#                                             'points_against': 107.16,
#                                             'points_for': 110.34,
#                                             'records': [{'losses': 2,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.889,
#                                                          'wins': 16},
#                                                         {'losses': 14,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.65,
#                                                          'wins': 26},
#                                                         {'losses': 8,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.5,
#                                                          'wins': 8},
#                                                         {'losses': 17,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.673,
#                                                          'wins': 35},
#                                                         {'losses': 8,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.5,
#                                                          'wins': 8},
#                                                         {'losses': 10,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.756,
#                                                          'wins': 31},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
# ...
#                                             'name': 'Nuggets',
#                                             'point_diff': 0.51,
#                                             'points_against': 111.21,
#                                             'points_for': 111.72,
#                                             'records': [{'losses': 4,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 18,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.571,
#                                                          'wins': 24},
#                                                         {'losses': 3,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 28,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.462,
#                                                          'wins': 24},
#                                                         {'losses': 10,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.375,
#                                                          'wins': 6},
#                                                         {'losses': 42,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.481,
#                                                          'wins': 39},
#                                                         {'losses': 42,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.481,
#                                                          'wins': 39},
#                                                         {'losses': 0,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 19,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.537,
#                                                          'wins': 22},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 0,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 10,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.375,
#                                                          'wins': 6},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 0,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0,
#                                                          'wins': 0},
#                                                         {'losses': 41,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.414,
#                                                          'wins': 29},
#                                                         {'losses': 3,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 24,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.4,
#                                                          'wins': 16},
#                                                         {'losses': 6,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.667,
#                                                          'wins': 12},
#                                                         {'losses': 23,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.439,
#                                                          'wins': 18},
#                                                         {'losses': 29,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.58,
#                                                          'wins': 40},
#                                                         {'losses': 7,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 12,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.333,
#                                                          'wins': 6},
#                                                         {'losses': 19,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.558,
#                                                          'wins': 24},
#                                                         {'losses': 10,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.333,
#                                                          'wins': 5}],
#                                             'reference': '1610612743',
#                                             'sr_id': 'sr:team:3417',
#                                             'streak': {'kind': 'win',
#                                                        'length': 2},
#                                             'win_pct': 0.488,
#                                             'wins': 40},
#                                            {'games_behind': {'conference': 36.0,
#                                                              'division': 20.0,
#                                                              'league': 36.0},
#                                             'id': '583eca2f-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 51,
#                                             'market': 'Minnesota',
#                                             'name': 'Timberwolves',
#                                             'point_diff': -1.11,
#                                             'points_against': 106.68,
#                                             'points_for': 105.57,
#                                             'records': [{'losses': 7,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 21,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.4,
#                                                          'wins': 14},
#                                                         {'losses': 6,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 34,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.346,
#                                                          'wins': 18},
#                                                         {'losses': 11,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.313,
#                                                          'wins': 5},
#                                                         {'losses': 21,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.488,
#                                                          'wins': 20},
#                                                         {'losses': 7,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 9,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.1,
#                                                          'wins': 1},
#                                                         {'losses': 11,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.313,
#                                                          'wins': 5},
#                                                         {'losses': 3,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.4,
#                                                          'wins': 2},
#                                                         {'losses': 30,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.362,
#                                                          'wins': 17},
#                                                         {'losses': 9,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.5,
#                                                          'wins': 9},
#                                                         {'losses': 30,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.268,
#                                                          'wins': 11},
#                                                         {'losses': 4,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 14,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.222,
#                                                          'wins': 4},
#                                                         {'losses': 19,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.486,
#                                                          'wins': 18},
#                                                         {'losses': 10,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.412,
#                                                          'wins': 7}],
#                                             'reference': '1610612750',
#                                             'sr_id': 'sr:team:3426',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 6},
#                                             'win_pct': 0.378,
#                                             'wins': 31}]}],
#                   'id': '7fe7e212-de01-4f8f-a31d-b9f0a95731e3',
#                   'name': 'WESTERN CONFERENCE'}],
#  'league': {'alias': 'NBA',
#             'id': '4353138d-4c22-4396-95d8-5f587d2df25c',
#             'name': 'NBA'},
#  'season': {'id': '03241c9e-731b-40d0-a36f-bcc9932d055b',
#             'type': 'REG',
#             'year': 2016}}

# %%
# Will attempt to use multi-layered loops to minimize lines of code.  Our goal is to collect data for each team.
# To do this will attempt a team loop within a division loop within a conference loop. 

# THIS WHOLE THING PROBABLY NEEDS TO BE SHIFTED OVER and SUBMERGED UNDER THE SEASON LOOP  HOW TO DO?

for conference in nba_response['conferences']:
    conference_name = conference['alias']
    print(f"Now analyzying teams in the {conference_name} conference")
    for division in conference["divisions"]:
        division_name = division['alias']
        print(f"Now analyzing teams in the {division_name} division of the {conference_name} conference")
        for team in division["teams"]:
            team_name = team['name']
            print(f"{team_name} is in the {division_name} division of the {conference_name} conference")
            teams.append(team_name)
            division_list.append(division_name)
            conference_list.append(conference_name)
            wins.append(team["wins"])
            losses.append(team["losses"])
            win_pct.append(team["win_pct"])
            points_for_list.append(team["points_for"])
            points_against_list.append(team["points_against"])
            cities.append(team['market'])
            season_list.append(season)
            team_count = len(teams)
        print(f"Team count is now {team_count}")
# Out:
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Team count is now 5
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Team count is now 10
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# Team count is now 15
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Team count is now 20
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Team count is now 25
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Team count is now 30

# %%
season_list
# Out:
# ['2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016']

# %%
len(season_list)
# Out:
# 30

# %%
NBA_df = pd.DataFrame({"Season": season_list, "City": cities,"Team": teams,"Conference": conference_list,"Division": division_list,"Wins": wins,"Losses": losses, "Win Pct.": win_pct,"Points For": points_for_list, "Points Against": points_against_list})

# %%
NBA_df
# Out:
#    Season           City           Team Conference   Division  Wins  Losses  \
# 0    2016     Washington        Wizards    EASTERN  SOUTHEAST    49      33
# 1    2016        Atlanta          Hawks    EASTERN  SOUTHEAST    43      39
# 2    2016          Miami           Heat    EASTERN  SOUTHEAST    41      41
# 3    2016      Charlotte        Hornets    EASTERN  SOUTHEAST    36      46
# 4    2016        Orlando          Magic    EASTERN  SOUTHEAST    29      53
# 5    2016      Cleveland      Cavaliers    EASTERN    CENTRAL    51      31
# 6    2016        Indiana         Pacers    EASTERN    CENTRAL    42      40
# 7    2016      Milwaukee          Bucks    EASTERN    CENTRAL    42      40
# 8    2016        Chicago          Bulls    EASTERN    CENTRAL    41      41
# 9    2016        Detroit        Pistons    EASTERN    CENTRAL    37      45
# 10   2016         Boston        Celtics    EASTERN   ATLANTIC    53      29
# 11   2016        Toronto        Raptors    EASTERN   ATLANTIC    51      31
# 12   2016       New York         Knicks    EASTERN   ATLANTIC    31      51
# 13   2016   Philadelphia          76ers    EASTERN   ATLANTIC    28      54
# 14   2016       Brooklyn           Nets    EASTERN   ATLANTIC    20      62
# 15   2016   Golden State       Warriors    WESTERN    PACIFIC    67      15
# 16   2016    Los Angeles       Clippers    WESTERN    PACIFIC    51      31
# 17   2016     Sacramento          Kings    WESTERN    PACIFIC    32      50
# 18   2016    Los Angeles         Lakers    WESTERN    PACIFIC    26      56
# 19   2016        Phoenix           Suns    WESTERN    PACIFIC    24      58
# 20   2016    San Antonio          Spurs    WESTERN  SOUTHWEST    61      21
# 21   2016        Houston        Rockets    WESTERN  SOUTHWEST    55      27
# 22   2016        Memphis      Grizzlies    WESTERN  SOUTHWEST    43      39
# 23   2016    New Orleans       Pelicans    WESTERN  SOUTHWEST    34      48
# 24   2016         Dallas      Mavericks    WESTERN  SOUTHWEST    33      49
# 25   2016           Utah           Jazz    WESTERN  NORTHWEST    51      31
# 26   2016  Oklahoma City        Thunder    WESTERN  NORTHWEST    47      35
# 27   2016       Portland  Trail Blazers    WESTERN  NORTHWEST    41      41
# 28   2016         Denver        Nuggets    WESTERN  NORTHWEST    40      42
# 29   2016      Minnesota   Timberwolves    WESTERN  NORTHWEST    31      51
#
#     Win Pct.  Points For  Points Against
# 0      0.598      109.18          107.38
# 1      0.524      103.16          104.01
# 2      0.500      103.17          102.11
# 3      0.439      104.89          104.70
# 4      0.354      101.07          107.65
# 5      0.622      110.34          107.16
# 6      0.512      105.10          105.32
# 7      0.512      103.62          103.81
# 8      0.500      102.87          102.44
# 9      0.451      101.33          102.45
# 10     0.646      108.01          105.38
# 11     0.622      106.85          102.65
# 12     0.378      104.34          108.01
# 13     0.341      102.44          108.13
# 14     0.244      105.77          112.50
# 15     0.817      115.89          104.26
# 16     0.622      108.67          104.38
# 17     0.390      102.81          106.68
# 18     0.317      104.57          111.45
# 19     0.293      107.70          113.33
# 20     0.744      105.33           98.13
# 21     0.671      115.34          109.57
# 22     0.524      100.48           99.99
# 23     0.415      104.34          106.44
# 24     0.402       97.92          100.84
# 25     0.622      100.71           96.77
# 26     0.573      106.60          105.84
# 27     0.500      107.94          108.46
# 28     0.488      111.72          111.21
# 29     0.378      105.57          106.68
